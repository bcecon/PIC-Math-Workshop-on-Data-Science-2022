# %% [markdown]
# # Example 1. Authorizing an application to access Twitter account data

# %%
import twitter
# Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'OYT3v8MByXqfVjdU49B64gQLB'
CONSUMER_SECRET ='QGFz5aa4CRXyVOWxgZQd2YxjcB5FjmK8y6QQkO39RdNbzOUJtG'
OAUTH_TOKEN = '571213367-016n5aGlN9TUNZ1dHvLBy55yKfM2PMFhSUmlE0Hf'
OAUTH_TOKEN_SECRET = '6gsjjbMrkGuJI9vvTXLcD2hhpmy2e1Cin0rmCpwJF81y6'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000021511D95D30>

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
# Out:
# [{'created_at': '2016-09-09T00:28:42Z', 'as_of': '2016-09-09T00:35:26Z', 'trends': [{'name': '#Gala1GH17', 'url': 'http://twitter.com/search?q=%23Gala1GH17', 'query': '%23Gala1GH17', 'promoted_content': None, 'tweet_volume': 427693}, {'name': '#iphone7emetropolitana', 'url': 'http://twitter.com/search?q=%23iphone7emetropolitana', 'query': '%23iphone7emetropolitana', 'promoted_content': None, 'tweet_volume': 69388}, {'name': '#NFLKickoff', 'url': 'http://twitter.com/search?q=%23NFLKickoff', 'query': '%23NFLKickoff', 'promoted_content': None, 'tweet_volume': 29030}, {'name': '#TBTENMTVHITS', 'url': 'http://twitter.com/search?q=%23TBTENMTVHITS', 'query': '%23TBTENMTVHITS', 'promoted_content': None, 'tweet_volume': None}, {'name': '#LaliEnElOpera', 'url': 'http://twitter.com/search?q=%23LaliEnElOpera', 'query': '%23LaliEnElOpera', 'promoted_content': None, 'tweet_volume': 21675}, {'name': 'Daniel Dias', 'url': 'http://twitter.com/search?q=%22Daniel+Dias%22', 'query': '%22Daniel+Dias%22', 'promoted_content': None, 'tweet_volume': 10003}, {'name': 'Von Miller', 'url': 'http://twitter.com/search?q=%22Von+Miller%22', 'query': '%22Von+Miller%22', 'promoted_content': None, 'tweet_volume': 41657}, {'name': 'Ángeles Ortiz', 'url': 'http://twitter.com/search?q=%22%C3%81ngeles+Ortiz%22', 'query': '%22%C3%81ngeles+Ortiz%22', 'promoted_content': None, 'tweet_volume': None}, {'name': '9 Years Of iCarly', 'url': 'http://twitter.com/search?q=%229+Years+Of+iCarly%22', 'query': '%229+Years+Of+iCarly%22', 'promoted_content': None, 'tweet_volume': None}, {'name': '既読機能', 'url': 'http://twitter.com/search?q=%E6%97%A2%E8%AA%AD%E6%A9%9F%E8%83%BD', 'query': '%E6%97%A2%E8%AA%AD%E6%A9%9F%E8%83%BD', 'promoted_content': None, 'tweet_volume': 10082}, {'name': 'Wells Fargo', 'url': 'http://twitter.com/search?q=%22Wells+Fargo%22', 'query': '%22Wells+Fargo%22', 'promoted_content': None, 'tweet_volume': 50209}, {'name': 'Marlone', 'url': 'http://twitter.com/search?q=Marlone', 'query': 'Marlone', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Pliskova', 'url': 'http://twitter.com/search?q=Pliskova', 'query': 'Pliskova', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Paulão', 'url': 'http://twitter.com/search?q=Paul%C3%A3o', 'query': 'Paul%C3%A3o', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Diego Souza', 'url': 'http://twitter.com/search?q=%22Diego+Souza%22', 'query': '%22Diego+Souza%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Sophia', 'url': 'http://twitter.com/search?q=Sophia', 'query': 'Sophia', 'promoted_content': None, 'tweet_volume': 106652}, {'name': 'Arrascaeta', 'url': 'http://twitter.com/search?q=Arrascaeta', 'query': 'Arrascaeta', 'promoted_content': None, 'tweet_volume': None}, {'name': '#قلبي_يهمس_لك', 'url': 'http://twitter.com/search?q=%23%D9%82%D9%84%D8%A8%D9%8A_%D9%8A%D9%87%D9%85%D8%B3_%D9%84%D9%83', 'query': '%23%D9%82%D9%84%D8%A8%D9%8A_%D9%8A%D9%87%D9%85%D8%B3_%D9%84%D9%83', 'promoted_content': None, 'tweet_volume': 13071}, {'name': '#whyTONIGHT', 'url': 'http://twitter.com/search?q=%23whyTONIGHT', 'query': '%23whyTONIGHT', 'promoted_content': None, 'tweet_volume': 31811}, {'name': '#MakeAMovieCaffeinated', 'url': 'http://twitter.com/search?q=%23MakeAMovieCaffeinated', 'query': '%23MakeAMovieCaffeinated', 'promoted_content': None, 'tweet_volume': 12354}, {'name': '#MafiaSeguindoGeral', 'url': 'http://twitter.com/search?q=%23MafiaSeguindoGeral', 'query': '%23MafiaSeguindoGeral', 'promoted_content': None, 'tweet_volume': 17967}, {'name': '#727TourPhoenix', 'url': 'http://twitter.com/search?q=%23727TourPhoenix', 'query': '%23727TourPhoenix', 'promoted_content': None, 'tweet_volume': 38471}, {'name': '#OSIRISREx', 'url': 'http://twitter.com/search?q=%23OSIRISREx', 'query': '%23OSIRISREx', 'promoted_content': None, 'tweet_volume': 13319}, {'name': '#حزب_اللي_يتحنون_قبل_العيد', 'url': 'http://twitter.com/search?q=%23%D8%AD%D8%B2%D8%A8_%D8%A7%D9%84%D9%84%D9%8A_%D9%8A%D8%AA%D8%AD%D9%86%D9%88%D9 ...

# %%
print(us_trends)
# Out:
# [{'created_at': '2016-09-09T00:25:32Z', 'as_of': '2016-09-09T00:31:46Z', 'trends': [{'name': '#NFLKickoff', 'url': 'http://twitter.com/search?q=%23NFLKickoff', 'query': '%23NFLKickoff', 'promoted_content': None, 'tweet_volume': 27402}, {'name': '#MakeAMovieCaffeinated', 'url': 'http://twitter.com/search?q=%23MakeAMovieCaffeinated', 'query': '%23MakeAMovieCaffeinated', 'promoted_content': None, 'tweet_volume': 11730}, {'name': '#OSIRISREx', 'url': 'http://twitter.com/search?q=%23OSIRISREx', 'query': '%23OSIRISREx', 'promoted_content': None, 'tweet_volume': 12713}, {'name': '#whyTONIGHT', 'url': 'http://twitter.com/search?q=%23whyTONIGHT', 'query': '%23whyTONIGHT', 'promoted_content': None, 'tweet_volume': 30814}, {'name': 'Wells Fargo', 'url': 'http://twitter.com/search?q=%22Wells+Fargo%22', 'query': '%22Wells+Fargo%22', 'promoted_content': None, 'tweet_volume': 48753}, {'name': 'Von Miller', 'url': 'http://twitter.com/search?q=%22Von+Miller%22', 'query': '%22Von+Miller%22', 'promoted_content': None, 'tweet_volume': 39104}, {'name': '#BackpackEssentialsIn3Words', 'url': 'http://twitter.com/search?q=%23BackpackEssentialsIn3Words', 'query': '%23BackpackEssentialsIn3Words', 'promoted_content': None, 'tweet_volume': None}, {'name': 'One Republic', 'url': 'http://twitter.com/search?q=%22One+Republic%22', 'query': '%22One+Republic%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Never Date A Feminist', 'url': 'http://twitter.com/search?q=%22Never+Date+A+Feminist%22', 'query': '%22Never+Date+A+Feminist%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Marshawn Lynch', 'url': 'http://twitter.com/search?q=%22Marshawn+Lynch%22', 'query': '%22Marshawn+Lynch%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Pliskova', 'url': 'http://twitter.com/search?q=Pliskova', 'query': 'Pliskova', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Phi Phi', 'url': 'http://twitter.com/search?q=%22Phi+Phi%22', 'query': '%22Phi+Phi%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Trevor Siemian', 'url': 'http://twitter.com/search?q=%22Trevor+Siemian%22', 'query': '%22Trevor+Siemian%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Team North America', 'url': 'http://twitter.com/search?q=%22Team+North+America%22', 'query': '%22Team+North+America%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Dierks Bentley', 'url': 'http://twitter.com/search?q=%22Dierks+Bentley%22', 'query': '%22Dierks+Bentley%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Trap or Die 3', 'url': 'http://twitter.com/search?q=%22Trap+or+Die+3%22', 'query': '%22Trap+or+Die+3%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Landon Donovan', 'url': 'http://twitter.com/search?q=%22Landon+Donovan%22', 'query': '%22Landon+Donovan%22', 'promoted_content': None, 'tweet_volume': 19280}, {'name': 'Ryan Howard', 'url': 'http://twitter.com/search?q=%22Ryan+Howard%22', 'query': '%22Ryan+Howard%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Rodney Harrison', 'url': 'http://twitter.com/search?q=%22Rodney+Harrison%22', 'query': '%22Rodney+Harrison%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Kelvin Benjamin', 'url': 'http://twitter.com/search?q=%22Kelvin+Benjamin%22', 'query': '%22Kelvin+Benjamin%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Kevin Kiermaier', 'url': 'http://twitter.com/search?q=%22Kevin+Kiermaier%22', 'query': '%22Kevin+Kiermaier%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Mary Matalin', 'url': 'http://twitter.com/search?q=%22Mary+Matalin%22', 'query': '%22Mary+Matalin%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'Jed York', 'url': 'http://twitter.com/search?q=%22Jed+York%22', 'query': '%22Jed+York%22', 'promoted_content': None, 'tweet_volume': None}, {'name': 'CC Sabathia', 'url': 'http://twitter.com/search?q=%22CC+Sabathia%22', 'query': '%22CC+Sabathia%22', 'promoted_cont ...

# %%
import json
data= json.dumps(us_trends, indent=1)

file = open('foo.txt','w')
file.write(data)
file.close()

# %%
file = open('foo.txt','r')
foo = file.read()
d = json.loads(foo)

print(len(d))
print(d[0].keys())
print(len(d[0]['trends']))
print(d[0]['trends'][27])
# Out:
# 1
# dict_keys(['created_at', 'as_of', 'trends', 'locations'])
# 50
# {'name': '#DangerousWomanTour', 'url': 'http://twitter.com/search?q=%23DangerousWomanTour', 'query': '%23DangerousWomanTour', 'promoted_content': None, 'tweet_volume': None}

# %%
b={'randy':47,'tyler':'cool'}
print(b['randy'])
print(b.keys())
# Out:
# 47
# dict_keys(['randy', 'tyler'])

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

#print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "created_at": "2016-09-09T00:30:31Z",
#   "as_of": "2016-09-09T00:35:26Z",
#   "trends": [
#    {
#     "name": "#NFLKickoff",
#     "url": "http://twitter.com/search?q=%23NFLKickoff",
#     "query": "%23NFLKickoff",
#     "promoted_content": null,
#     "tweet_volume": 29498
#    },
#    {
#     "name": "#MakeAMovieCaffeinated",
#     "url": "http://twitter.com/search?q=%23MakeAMovieCaffeinated",
#     "query": "%23MakeAMovieCaffeinated",
#     "promoted_content": null,
#     "tweet_volume": 11960
#    },
#    {
#     "name": "Von Miller",
#     "url": "http://twitter.com/search?q=%22Von+Miller%22",
#     "query": "%22Von+Miller%22",
#     "promoted_content": null,
#     "tweet_volume": 40484
#    },
#    {
#     "name": "#OSIRISREx",
#     "url": "http://twitter.com/search?q=%23OSIRISREx",
#     "query": "%23OSIRISREx",
#     "promoted_content": null,
#     "tweet_volume": 12896
#    },
#    {
#     "name": "Wells Fargo",
#     "url": "http://twitter.com/search?q=%22Wells+Fargo%22",
#     "query": "%22Wells+Fargo%22",
#     "promoted_content": null,
#     "tweet_volume": 49226
#    },
#    {
#     "name": "#whyTONIGHT",
#     "url": "http://twitter.com/search?q=%23whyTONIGHT",
#     "query": "%23whyTONIGHT",
#     "promoted_content": null,
#     "tweet_volume": 30901
#    },
#    {
#     "name": "#BackpackEssentialsIn3Words",
#     "url": "http://twitter.com/search?q=%23BackpackEssentialsIn3Words",
#     "query": "%23BackpackEssentialsIn3Words",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "One Republic",
#     "url": "http://twitter.com/search?q=%22One+Republic%22",
#     "query": "%22One+Republic%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Never Date A Feminist",
#     "url": "http://twitter.com/search?q=%22Never+Date+A+Feminist%22",
#     "query": "%22Never+Date+A+Feminist%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Pliskova",
#     "url": "http://twitter.com/search?q=Pliskova",
#     "query": "Pliskova",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Marshawn Lynch",
#     "url": "http://twitter.com/search?q=%22Marshawn+Lynch%22",
#     "query": "%22Marshawn+Lynch%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Phi Phi",
#     "url": "http://twitter.com/search?q=%22Phi+Phi%22",
#     "query": "%22Phi+Phi%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Trevor Siemian",
#     "url": "http://twitter.com/search?q=%22Trevor+Siemian%22",
#     "query": "%22Trevor+Siemian%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Team North America",
#     "url": "http://twitter.com/search?q=%22Team+North+America%22",
#     "query": "%22Team+North+America%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Dierks Bentley",
#     "url": "http://twitter.com/search?q=%22Dierks+Bentley%22",
#     "query": "%22Dierks+Bentley%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "FOOTBALL IS BACK",
#     "url": "http://twitter.com/search?q=%22FOOTBALL+IS+BACK%22",
#     "query": "%22FOOTBALL+IS+BACK%22",
#     "promoted_content": null,
#     "tweet_volume": 20415
#    },
#    {
#     "name": "Trap or Die 3",
#     "url": "http://twitter.com/search?q=%22Trap+or+Die+3%22",
#     "query": "%22Trap+or+Die+3%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Landon Donovan",
#     "url": "http://twitter.com/search?q=%22Landon+Donovan%22",
#     "query": "%22Landon+Donovan%22",
#     "promoted_content": null,
#     "tweet_volume": 19374
#    },
#    {
#     "name": "Ryan Howard",
#     "url": "http://twitter.com/search?q=%22Ryan+Howard%22",
#     "query": "%22Ryan+Howard%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Kelvin Benjamin",
#     "url": "http://twitter.com/search?q=%22Kelvin+Benjamin%22",
#     "query": "%22Kelvin+Benjamin%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Kevin Kiermaier",
#     "url": "http://twitter.com/search?q=%22Kevin+Kiermaier%22",
#     "query": "%22Kevin+Kiermaier%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Jed York",
#     "url": "http://twitter.com/search?q=%22Jed+York%22",
#     "query": "%22Jed+York%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "Brian McCann",
#     "url": "http://twitter.com/search?q=%22Brian+McCann%22",
#     "query": "%22Brian+McCann%22",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#Gala1GH17",
#     "url": "http://twitter.com/search?q=%23Gala1GH17",
#     "query": "%23Gala1GH17",
#     "promoted_content": null,
#     "tweet_volume": 416062
#    },
#    {
#     "name": "#DELETEorDECAY",
#     "url": "http://twitter.com/search?q=%23DELETEorDECAY",
#     "query": "%23DELETEorDECAY",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#hardball",
#     "url": "http://twitter.com/search?q=%23hardball",
#     "query": "%23hardball",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#LiveByNight",
#     "url": "http://twitter.com/search?q=%23LiveByNight",
#     "query": "%23LiveByNight",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#DangerousWomanTour",
#     "url": "http://twitter.com/search?q=%23DangerousWomanTour",
#     "query": "%23DangerousWomanTour",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#FacesOfTheClique",
#     "url": "http://twitter.com/search?q=%23FacesOfTheClique",
#     "query": "%23FacesOfTheClique",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#thingstrumpwouldhavestopped",
#     "url": "http://twitter.com/search?q=%23thingstrumpwouldhavestopped",
#     "query": "%23thingstrumpwouldhavestopped",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#HERstoryOfTheWorld",
#     "url": "http://twitter.com/search?q=%23HERstoryOfTheWorld",
#     "query": "%23HERstoryOfTheWorld",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#MixersEndedHarmonizersParty",
#     "url": "http://twitter.com/search?q=%23MixersEndedHarmonizersParty",
#     "query": "%23MixersEndedHarmonizersParty",
#     "promoted_content": null,
#     "tweet_volume": 76784
#    },
#    {
#     "name": "#BodyPosiForWes",
#     "url": "http://twitter.com/search?q=%23BodyPosiForWes",
#     "query": "%23BodyPosiForWes",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#IfAnimalsRuled",
#     "url": "http://twitter.com/search?q=%23IfAnimalsRuled",
#     "query": "%23IfAnimalsRuled",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#GlobalEdChat",
#     "url": "http://twitter.com/search?q=%23GlobalEdChat",
#     "query": "%23GlobalEdChat",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#MovieFightsLive",
#     "url": "http://twitter.com/search?q=%23MovieFightsLive",
#     "query": "%23MovieFightsLive",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#MyEpitaphWouldSay",
#     "url": "http://twitter.com/search?q=%23MyEpitaphWouldSay",
#     "query": "%23MyEpitaphWouldSay",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#askjustine",
#     "url": "http://twitter.com/search?q=%23askjustine",
#     "query": "%23askjustine",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#HackMeAlli",
#     "url": "http://twitter.com/search?q=%23HackMeAlli",
#     "query": "%23HackMeAlli",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#SNTIC",
#     "url": "http://twitter.com/search?q=%23SNTIC",
#     "query": "%23SNTIC",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#whatisschool",
#     "url": "http://twitter.com/search?q=%23whatisschool",
#     "query": "%23whatisschool",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#SeesawChat",
#     "url": "http://twitter.com/search?q=%23SeesawChat",
#     "query": "%23SeesawChat",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#AleppoGate",
#     "url": "http://twitter.com/search?q=%23AleppoGate",
#     "query": "%23AleppoGate",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#727TourPhoenix",
#     "url": "http://twitter.com/search?q=%23727TourPhoenix",
#     "query": "%23727TourPhoenix",
#     "promoted_content": null,
#     "tweet_volume": 37839
#    },
#    {
#     "name": "#Superbalanced",
#     "url": "http://twitter.com/search?q=%23Superbalanced",
#     "query": "%23Superbalanced",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#bbcqt",
#     "url": "http://twitter.com/search?q=%23bbcqt",
#     "query": "%23bbcqt",
#     "promoted_content": null,
#     "tweet_volume": 70590
#    },
#    {
#     "name": "#ThirstyThursday",
#     "url": "http://twitter.com/search?q=%23ThirstyThursday",
#     "query": "%23ThirstyThursday",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#IlluminateExperience",
#     "url": "http://twitter.com/search?q=%23IlluminateExperience",
#     "query": "%23IlluminateExperience",
#     "promoted_content": null,
#     "tweet_volume": 20762
#    },
#    {
#     "name": "#10YearsRising",
#     "url": "http://twitter.com/search?q=%2310YearsRising",
#     "query": "%2310YearsRising",
#     "promoted_content": null,
#     "tweet_volume": null
#    },
#    {
#     "name": "#TeFuisteYTeLlevaste",
#     "url": "http://twitter.com/search?q=%23TeFuisteYTeLlevaste",
#     "query": "%23TeFuisteYTeLlevaste",
#     "promoted_content": null,
#     "tweet_volume": 14776
#    }
#   ],
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
len(us_trends[0]['trends'])
for i in range(50):
    print(us_trends[0]['trends'][i]['url'])
    print(us_trends[0]['trends'][i]['query'])
# Out:
# http://twitter.com/search?q=%23NFLKickoff
# %23NFLKickoff
# http://twitter.com/search?q=%23MakeAMovieCaffeinated
# %23MakeAMovieCaffeinated
# http://twitter.com/search?q=%22Von+Miller%22
# %22Von+Miller%22
# http://twitter.com/search?q=%23OSIRISREx
# %23OSIRISREx
# http://twitter.com/search?q=%22Wells+Fargo%22
# %22Wells+Fargo%22
# http://twitter.com/search?q=%23whyTONIGHT
# %23whyTONIGHT
# http://twitter.com/search?q=%23BackpackEssentialsIn3Words
# %23BackpackEssentialsIn3Words
# http://twitter.com/search?q=%22One+Republic%22
# %22One+Republic%22
# http://twitter.com/search?q=%22Never+Date+A+Feminist%22
# %22Never+Date+A+Feminist%22
# http://twitter.com/search?q=Pliskova
# Pliskova
# http://twitter.com/search?q=%22Marshawn+Lynch%22
# %22Marshawn+Lynch%22
# http://twitter.com/search?q=%22Phi+Phi%22
# %22Phi+Phi%22
# http://twitter.com/search?q=%22Trevor+Siemian%22
# %22Trevor+Siemian%22
# http://twitter.com/search?q=%22Team+North+America%22
# %22Team+North+America%22
# http://twitter.com/search?q=%22Dierks+Bentley%22
# %22Dierks+Bentley%22
# http://twitter.com/search?q=%22FOOTBALL+IS+BACK%22
# %22FOOTBALL+IS+BACK%22
# http://twitter.com/search?q=%22Trap+or+Die+3%22
# %22Trap+or+Die+3%22
# http://twitter.com/search?q=%22Landon+Donovan%22
# %22Landon+Donovan%22
# http://twitter.com/search?q=%22Ryan+Howard%22
# %22Ryan+Howard%22
# http://twitter.com/search?q=%22Kelvin+Benjamin%22
# %22Kelvin+Benjamin%22
# http://twitter.com/search?q=%22Kevin+Kiermaier%22
# %22Kevin+Kiermaier%22
# http://twitter.com/search?q=%22Jed+York%22
# %22Jed+York%22
# http://twitter.com/search?q=%22Brian+McCann%22
# %22Brian+McCann%22
# http://twitter.com/search?q=%23Gala1GH17
# %23Gala1GH17
# http://twitter.com/search?q=%23DELETEorDECAY
# %23DELETEorDECAY
# http://twitter.com/search?q=%23hardball
# %23hardball
# http://twitter.com/search?q=%23LiveByNight
# %23LiveByNight
# http://twitter.com/search?q=%23DangerousWomanTour
# %23DangerousWomanTour
# http://twitter.com/search?q=%23FacesOfTheClique
# %23FacesOfTheClique
# http://twitter.com/search?q=%23thingstrumpwouldhavestopped
# %23thingstrumpwouldhavestopped
# http://twitter.com/search?q=%23HERstoryOfTheWorld
# %23HERstoryOfTheWorld
# http://twitter.com/search?q=%23MixersEndedHarmonizersParty
# %23MixersEndedHarmonizersParty
# http://twitter.com/search?q=%23BodyPosiForWes
# %23BodyPosiForWes
# http://twitter.com/search?q=%23IfAnimalsRuled
# %23IfAnimalsRuled
# http://twitter.com/search?q=%23GlobalEdChat
# %23GlobalEdChat
# http://twitter.com/search?q=%23MovieFightsLive
# %23MovieFightsLive
# http://twitter.com/search?q=%23MyEpitaphWouldSay
# %23MyEpitaphWouldSay
# http://twitter.com/search?q=%23askjustine
# %23askjustine
# http://twitter.com/search?q=%23HackMeAlli
# %23HackMeAlli
# http://twitter.com/search?q=%23SNTIC
# %23SNTIC
# http://twitter.com/search?q=%23whatisschool
# %23whatisschool
# http://twitter.com/search?q=%23SeesawChat
# %23SeesawChat
# http://twitter.com/search?q=%23AleppoGate
# %23AleppoGate
# http://twitter.com/search?q=%23727TourPhoenix
# %23727TourPhoenix
# http://twitter.com/search?q=%23Superbalanced
# %23Superbalanced
# http://twitter.com/search?q=%23bbcqt
# %23bbcqt
# http://twitter.com/search?q=%23ThirstyThursday
# %23ThirstyThursday
# http://twitter.com/search?q=%23IlluminateExperience
# %23IlluminateExperience
# http://twitter.com/search?q=%2310YearsRising
# %2310YearsRising
# http://twitter.com/search?q=%23TeFuisteYTeLlevaste
# %23TeFuisteYTeLlevaste

# %% [markdown]
# # Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'#BackpackEssentialsIn3Words', '#DangerousWomanTour', 'Wells Fargo', '#MakeAMovieCaffeinated', 'Von Miller', '#whyTONIGHT', '#NFLKickoff', '#727TourPhoenix', '#OSIRISREx', '#bbcqt', '#Gala1GH17', '#TeFuisteYTeLlevaste', 'Pliskova', '#MixersEndedHarmonizersParty'}

# %%
world_trends[0]['trends'][0]['name']
# Out:
# '#Gala1GH17'

# %%
world_trends_set
# Out:
# {'#727TourPhoenix',
#  '#9Eylül',
#  '#BackpackEssentialsIn3Words',
#  '#BastilleWildWorld',
#  '#BuGeceMesajım',
#  '#CosasParaHacerAntesDeMorir',
#  '#DangerousWomanTour',
#  '#EsParaPresumir',
#  '#Gala1GH17',
#  '#Gangland',
#  '#GermanResponde',
#  '#LaVerdadDeAntonio',
#  '#LaliEnElOpera',
#  '#MafiaSeguindoGeral',
#  '#MakeAMovieCaffeinated',
#  '#MixersEndedHarmonizersParty',
#  '#NFLKickoff',
#  '#NoTengoDineroPero',
#  '#OSIRISREx',
#  '#Parapetado',
#  '#PersecucionAJueces',
#  '#RevocatorioYAoRebelion',
#  '#RosarioSangra',
#  '#TBTENMTVHITS',
#  '#TeFuisteYTeLlevaste',
#  '#TudoPelaNFL',
#  '#WeLoveYouAlly',
#  '#bbcqt',
#  '#iphone7emetropolitana',
#  '#whyTONIGHT',
#  '#ازاي_بتفتح_مواضيع',
#  '#جامعه_ام_القري',
#  '#حزب_اللي_يتحنون_قبل_العيد',
#  '#فرحتك_تكمل',
#  '#قلبي_يهمس_لك',
#  '#ماعافك_الخاطر_الا',
#  '#نبيل_شعيب_يغتصب_محمد_عبده',
#  '#يارب_اوعدنا_ب',
#  '9 Years Of iCarly',
#  'Arrascaeta',
#  'Daniel Dias',
#  'Diego Souza',
#  'Marlone',
#  'Paulão',
#  'Pliskova',
#  'Sophia',
#  'Von Miller',
#  'Wells Fargo',
#  'Ángeles Ortiz',
#  '既読機能'}

# %%
print(u'#\u0645\u0639\u0644\u0645\u064a\u0646_\u0627\u0644\u0627\u0631\u0628\u0639_\u0639\u0627\u0644\u0631\u0627\u062f\u064a\u0648_9090')
# Out:
# #معلمين_الاربع_عالراديو_9090

# %%
print(u'#\u0628\u0642\u0648\u0644_\u0643\u0641\u0627\u064a\u0647_\u0644')
# Out:
# #بقول_كفايه_ل

# %% [markdown]
# # Example 5. Collecting search results

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json

q = '#Kanye' 

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Length of statuses 81
# [
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 0,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "place": null,
#         "user": {
#             "url": null,
#             "created_at": "Fri Sep 02 01:58:07 +0000 2011",
#             "contributors_enabled": false,
#             "geo_enabled": true,
#             "verified": false,
#             "profile_text_color": "5E412F",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/434013979308859392/75jNNfRK_normal.jpeg",
#             "following": false,
#             "listed_count": 1,
#             "profile_sidebar_border_color": "F0A830",
#             "location": "Looking for a Great Perhaps",
#             "friends_count": 151,
#             "screen_name": "PhotobeatFlash",
#             "profile_background_tile": true,
#             "profile_link_color": "35C2CC",
#             "protected": false,
#             "statuses_count": 2190,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/366371625/1392312263",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/434013979308859392/75jNNfRK_normal.jpeg",
#             "has_extended_profile": false,
#             "name": "Samantha Huckuntod",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000133712030/At0FEEm3.png",
#             "id": 366371625,
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000133712030/At0FEEm3.png",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "notifications": false,
#             "utc_offset": -18000,
#             "profile_background_color": "FCEBB6",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "78C0A8",
#             "default_profile": false,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "followers_count": 148,
#             "is_translator": false,
#             "time_zone": "Central Time (US & Canada)",
#             "favourites_count": 2987,
#             "default_profile_image": false,
#             "id_str": "366371625",
#             "description": "See you later, Thug Life."
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Fri Sep 09 00:45:41 +0000 2016",
#         "id": 774046081587945473,
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "And Kanye falls victim to my \"their older albums were better\" comments. Join the club #kanye #falloutboy #panicatthedisco",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         86,
#                         92
#                     ],
#                     "text": "kanye"
#                 },
#                 {
#                     "indices": [
#                         93,
#                         104
#                     ],
#                     "text": "falloutboy"
#                 },
#                 {
#                     "indices": [
#                         105,
#                         121
#                     ],
#                     "text": "panicatthedisco"
#                 }
#             ],
#             "urls": []
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774046081587945473"
#     },
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 0,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "possibly_sensitive": false,
#         "place": null,
#         "user": {
#             "url": "https://t.co/qm0giClW69",
#             "created_at": "Thu Mar 05 12:25:47 +0000 2009",
#             "contributors_enabled": false,
#             "geo_enabled": true,
#             "verified": false,
#             "profile_text_color": "080D09",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/767535012795351040/Q7nkkaS0_normal.jpg",
#             "following": false,
#             "listed_count": 11,
#             "profile_sidebar_border_color": "181A1E",
#             "location": "DC ",
#             "friends_count": 426,
#             "screen_name": "MAWGM",
#             "profile_background_tile": true,
#             "profile_link_color": "040101",
#             "protected": false,
#             "statuses_count": 78113,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/22912572/1348495918",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/767535012795351040/Q7nkkaS0_normal.jpg",
#             "has_extended_profile": false,
#             "name": "MWGetMoney",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/90205262/crazycar.jpg",
#             "id": 22912572,
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/90205262/crazycar.jpg",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "notifications": false,
#             "utc_offset": -25200,
#             "profile_background_color": "FFFFFF",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "AAB3AA",
#             "default_profile": false,
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/qm0giClW69",
#                             "expanded_url": "http://www.facebook.com/Mwatson9",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "display_url": "facebook.com/Mwatson9"
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "followers_count": 725,
#             "is_translator": false,
#             "time_zone": "Pacific Time (US & Canada)",
#             "favourites_count": 3705,
#             "default_profile_image": false,
#             "id_str": "22912572",
#             "description": "IMPORTANT PERSON TO THOSE OF IMPORTANCE #UMDalumni Writer/Contributor"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Fri Sep 09 00:45:41 +0000 2016",
#         "id": 774046080325615616,
#         "extended_entities": {
#             "media": [
#                 {
#                     "indices": [
#                         35,
#                         58
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/Cr32zSlVIAAJwVE.jpg",
#                     "sizes": {
#                         "medium": {
#                             "resize": "fit",
#                             "w": 900,
#                             "h": 1200
#                         },
#                         "thumb": {
#                             "resize": "crop",
#                             "w": 150,
#                             "h": 150
#                         },
#                         "small": {
#                             "resize": "fit",
#                             "w": 510,
#                             "h": 680
#                         },
#                         "large": {
#                             "resize": "fit",
#                             "w": 960,
#                             "h": 1280
#                         }
#                     },
#                     "id": 774046071999766528,
#                     "expanded_url": "https://twitter.com/MAWGM/status/774046080325615616/photo/1",
#                     "media_url_https": "https://pbs.twimg.com/media/Cr32zSlVIAAJwVE.jpg",
#                     "url": "https://t.co/pgxhqGxHPl",
#                     "type": "photo",
#                     "id_str": "774046071999766528",
#                     "display_url": "pic.twitter.com/pgxhqGxHPl"
#                 }
#             ]
#         },
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "Waiting for #Kanye #SaintPabloTour https://t.co/pgxhqGxHPl",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         12,
#                         18
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         19,
#                         34
#                     ],
#                     "text": "SaintPabloTour"
#                 }
#             ],
#             "media": [
#                 {
#                     "indices": [
#                         35,
#                         58
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/Cr32zSlVIAAJwVE.jpg",
#                     "sizes": {
#                         "medium": {
#                             "resize": "fit",
#                             "w": 900,
#                             "h": 1200
#                         },
#                         "thumb": {
#                             "resize": "crop",
#                             "w": 150,
#                             "h": 150
#                         },
#                         "small": {
#                             "resize": "fit",
#                             "w": 510,
#                             "h": 680
#                         },
#                         "large": {
#                             "resize": "fit",
#                             "w": 960,
#                             "h": 1280
#                         }
#                     },
#                     "id": 774046071999766528,
#                     "expanded_url": "https://twitter.com/MAWGM/status/774046080325615616/photo/1",
#                     "media_url_https": "https://pbs.twimg.com/media/Cr32zSlVIAAJwVE.jpg",
#                     "url": "https://t.co/pgxhqGxHPl",
#                     "type": "photo",
#                     "id_str": "774046071999766528",
#                     "display_url": "pic.twitter.com/pgxhqGxHPl"
#                 }
#             ],
#             "urls": []
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774046080325615616"
#     },
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 0,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "place": null,
#         "user": {
#             "url": null,
#             "created_at": "Tue Mar 25 00:49:23 +0000 2014",
#             "contributors_enabled": false,
#             "geo_enabled": true,
#             "verified": false,
#             "profile_text_color": "333333",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/752022796453023744/fmUZ0CjV_normal.jpg",
#             "following": false,
#             "listed_count": 4,
#             "profile_sidebar_border_color": "C0DEED",
#             "location": "",
#             "friends_count": 391,
#             "screen_name": "OgJuanKTA",
#             "profile_background_tile": false,
#             "profile_link_color": "0084B4",
#             "protected": false,
#             "statuses_count": 12893,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2409792146/1471589277",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/752022796453023744/fmUZ0CjV_normal.jpg",
#             "has_extended_profile": false,
#             "name": "PAbl\u00f8",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "id": 2409792146,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "notifications": false,
#             "utc_offset": null,
#             "profile_background_color": "C0DEED",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "default_profile": true,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "followers_count": 437,
#             "is_translator": false,
#             "time_zone": null,
#             "favourites_count": 3876,
#             "default_profile_image": false,
#             "id_str": "2409792146",
#             "description": "OCEAN BOYZ"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Fri Sep 09 00:44:53 +0000 2016",
#         "id": 774045879711838210,
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "anyone selling tickets for Kanye West in Dallas? HMU need 2 #SaintPabloTour #kanye #dallas #AmericanAirlines",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         60,
#                         75
#                     ],
#                     "text": "SaintPabloTour"
#                 },
#                 {
#                     "indices": [
#                         76,
#                         82
#                     ],
#                     "text": "kanye"
#                 },
#                 {
#                     "indices": [
#                         83,
#                         90
#                     ],
#                     "text": "dallas"
#                 },
#                 {
#                     "indices": [
#                         91,
#                         108
#                     ],
#                     "text": "AmericanAirlines"
#                 }
#             ],
#             "urls": []
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774045879711838210"
#     },
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 0,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "possibly_sensitive": false,
#         "place": null,
#         "user": {
#             "url": "https://t.co/hfr6B5F3Pu",
#             "created_at": "Fri Sep 11 18:53:20 +0000 2015",
#             "contributors_enabled": false,
#             "geo_enabled": true,
#             "verified": false,
#             "profile_text_color": "333333",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/705126528112177152/WmFTarSm_normal.jpg",
#             "following": false,
#             "listed_count": 0,
#             "profile_sidebar_border_color": "C0DEED",
#             "location": "",
#             "friends_count": 76,
#             "screen_name": "exstenceapparel",
#             "profile_background_tile": false,
#             "profile_link_color": "0084B4",
#             "protected": false,
#             "statuses_count": 255,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3529660213/1470534740",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/705126528112177152/WmFTarSm_normal.jpg",
#             "has_extended_profile": false,
#             "name": "Existence Apparel\u00ae",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "id": 3529660213,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "notifications": false,
#             "utc_offset": null,
#             "profile_background_color": "C0DEED",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "default_profile": true,
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/hfr6B5F3Pu",
#                             "expanded_url": "http://www.existenceapparel.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "display_url": "existenceapparel.com"
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/eVoo9Xwgkt",
#                             "expanded_url": "https://youtu.be/iLd5nZOhVPs",
#                             "indices": [
#                                 79,
#                                 102
#                             ],
#                             "display_url": "youtu.be/iLd5nZOhVPs"
#                         }
#                     ]
#                 }
#             },
#             "followers_count": 145,
#             "is_translator": false,
#             "time_zone": null,
#             "favourites_count": 104,
#             "default_profile_image": false,
#             "id_str": "3529660213",
#             "description": "Lifestyle brand | Exist From Within | Make Your Existence Worth While | MYEWW| https://t.co/eVoo9Xwgkt"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Fri Sep 09 00:44:21 +0000 2016",
#         "id": 774045747742257152,
#         "extended_entities": {
#             "media": [
#                 {
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/Cr32gALVUAAh8lR.jpg",
#                     "sizes": {
#                         "small": {
#                             "resize": "fit",
#                             "w": 680,
#                             "h": 680
#                         },
#                         "thumb": {
#                             "resize": "crop",
#                             "w": 150,
#                             "h": 150
#                         },
#                         "medium": {
#                             "resize": "fit",
#                             "w": 750,
#                             "h": 750
#                         },
#                         "large": {
#                             "resize": "fit",
#                             "w": 750,
#                             "h": 750
#                         }
#                     },
#                     "id": 774045740641374208,
#                     "expanded_url": "https://twitter.com/exstenceapparel/status/774045747742257152/photo/1",
#                     "media_url_https": "https://pbs.twimg.com/media/Cr32gALVUAAh8lR.jpg",
#                     "url": "https://t.co/FdTtrN9CdW",
#                     "type": "photo",
#                     "id_str": "774045740641374208",
#                     "display_url": "pic.twitter.com/FdTtrN9CdW"
#                 }
#             ]
#         },
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "Real friends. How many of us? How many jealous? Saturday Sept.17th Fall '16 drops! \ud83c\udf0a #existenceapparel #kanye #yeezy https://t.co/FdTtrN9CdW",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         85,
#                         102
#                     ],
#                     "text": "existenceapparel"
#                 },
#                 {
#                     "indices": [
#                         103,
#                         109
#                     ],
#                     "text": "kanye"
#                 },
#                 {
#                     "indices": [
#                         110,
#                         116
#                     ],
#                     "text": "yeezy"
#                 }
#             ],
#             "media": [
#                 {
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/Cr32gALVUAAh8lR.jpg",
#                     "sizes": {
#                         "small": {
#                             "resize": "fit",
#                             "w": 680,
#                             "h": 680
#                         },
#                         "thumb": {
#                             "resize": "crop",
#                             "w": 150,
#                             "h": 150
#                         },
#                         "medium": {
#                             "resize": "fit",
#                             "w": 750,
#                             "h": 750
#                         },
#                         "large": {
#                             "resize": "fit",
#                             "w": 750,
#                             "h": 750
#                         }
#                     },
#                     "id": 774045740641374208,
#                     "expanded_url": "https://twitter.com/exstenceapparel/status/774045747742257152/photo/1",
#                     "media_url_https": "https://pbs.twimg.com/media/Cr32gALVUAAh8lR.jpg",
#                     "url": "https://t.co/FdTtrN9CdW",
#                     "type": "photo",
#                     "id_str": "774045740641374208",
#                     "display_url": "pic.twitter.com/FdTtrN9CdW"
#                 }
#             ],
#             "urls": []
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774045747742257152"
#     },
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 0,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "place": null,
#         "user": {
#             "url": null,
#             "created_at": "Wed Sep 08 03:50:34 +0000 2010",
#             "contributors_enabled": false,
#             "geo_enabled": false,
#             "verified": false,
#             "profile_text_color": "333333",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/576567664623124481/maXoDnvz_normal.jpeg",
#             "following": false,
#             "listed_count": 18,
#             "profile_sidebar_border_color": "C0DEED",
#             "location": "",
#             "friends_count": 952,
#             "screen_name": "TapasChef",
#             "profile_background_tile": false,
#             "profile_link_color": "0084B4",
#             "protected": false,
#             "statuses_count": 5342,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/576567664623124481/maXoDnvz_normal.jpeg",
#             "has_extended_profile": false,
#             "name": "Adam Greenberg",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "id": 188193234,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "notifications": false,
#             "utc_offset": null,
#             "profile_background_color": "C0DEED",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "default_profile": true,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "followers_count": 916,
#             "is_translator": false,
#             "time_zone": null,
#             "favourites_count": 758,
#             "default_profile_image": false,
#             "id_str": "188193234",
#             "description": "@foodnetwork 3x #Chopped Grand Champion!    All things Food, Sports, Music, @annabridget & #snoopgreenberg lover"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Fri Sep 09 00:39:52 +0000 2016",
#         "id": 774044615855005697,
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "Anyone in #DC need a #kanye ticket right now? Heading into show and have one extra. Can transfer ticket electronically",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         10,
#                         13
#                     ],
#                     "text": "DC"
#                 },
#                 {
#                     "indices": [
#                         21,
#                         27
#                     ],
#                     "text": "kanye"
#                 }
#             ],
#             "urls": []
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774044615855005697"
#     },
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 1,
#         "possibly_sensitive": false,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "place": null,
#         "retweeted_status": {
#             "in_reply_to_screen_name": null,
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "lang": "en",
#             "retweet_count": 1,
#             "geo": null,
#             "in_reply_to_status_id": null,
#             "coordinates": null,
#             "favorite_count": 0,
#             "possibly_sensitive": false,
#             "place": null,
#             "user": {
#                 "url": "https://t.co/7RyNbqevi4",
#                 "created_at": "Sun Aug 30 07:29:35 +0000 2015",
#                 "contributors_enabled": false,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "profile_text_color": "000000",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/674178732106653696/QDmCiXLe_normal.jpg",
#                 "following": false,
#                 "listed_count": 10,
#                 "profile_sidebar_border_color": "000000",
#                 "location": "",
#                 "friends_count": 132,
#                 "screen_name": "underground_ng",
#                 "profile_background_tile": true,
#                 "profile_link_color": "FA743E",
#                 "protected": false,
#                 "statuses_count": 1882,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/3488747777/1459948916",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/674178732106653696/QDmCiXLe_normal.jpg",
#                 "has_extended_profile": false,
#                 "name": "#HipHopCommunity",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "id": 3488747777,
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "lang": "en",
#                 "follow_request_sent": false,
#                 "profile_use_background_image": true,
#                 "notifications": false,
#                 "utc_offset": null,
#                 "profile_background_color": "C0DEED",
#                 "is_translation_enabled": false,
#                 "profile_sidebar_fill_color": "000000",
#                 "default_profile": false,
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/7RyNbqevi4",
#                                 "expanded_url": "http://www.undergroundcontest.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "display_url": "undergroundcontest.com"
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "followers_count": 205,
#                 "is_translator": false,
#                 "time_zone": null,
#                 "favourites_count": 72,
#                 "default_profile_image": false,
#                 "id_str": "3488747777",
#                 "description": "Africa's No.1 Hip-Hop Community.                                 \nEnquiries: info@undergroundcontest.com"
#             },
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "in_reply_to_user_id": null,
#             "created_at": "Fri Sep 09 00:24:03 +0000 2016",
#             "id": 774040637758840832,
#             "contributors": null,
#             "in_reply_to_user_id_str": null,
#             "text": "[WATCH VIDEO] Teyana Taylor Brings Kanye West's \"Fade\" Video to Life (Explicit) - https://t.co/IErycULCY6\n#Kanye #yeezy #KanyeWest",
#             "retweeted": false,
#             "is_quote_status": false,
#             "entities": {
#                 "user_mentions": [],
#                 "symbols": [],
#                 "hashtags": [
#                     {
#                         "indices": [
#                             106,
#                             112
#                         ],
#                         "text": "Kanye"
#                     },
#                     {
#                         "indices": [
#                             113,
#                             119
#                         ],
#                         "text": "yeezy"
#                     },
#                     {
#                         "indices": [
#                             120,
#                             130
#                         ],
#                         "text": "KanyeWest"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/IErycULCY6",
#                         "expanded_url": "http://undergroundcontest.com/kanye-west-fade-explicit/",
#                         "indices": [
#                             82,
#                             105
#                         ],
#                         "display_url": "undergroundcontest.com/kanye-west-fad\u2026"
#                     }
#                 ]
#             },
#             "favorited": false,
#             "in_reply_to_status_id_str": null,
#             "truncated": false,
#             "id_str": "774040637758840832"
#         },
#         "user": {
#             "url": "https://t.co/siyuFNUGnc",
#             "created_at": "Mon Oct 31 23:47:55 +0000 2011",
#             "contributors_enabled": false,
#             "geo_enabled": false,
#             "verified": false,
#             "profile_text_color": "000000",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/667991763152461824/o-b7GyeK_normal.jpg",
#             "following": false,
#             "listed_count": 6,
#             "profile_sidebar_border_color": "000000",
#             "location": "Worldwide",
#             "friends_count": 316,
#             "screen_name": "BETVofficial",
#             "profile_background_tile": false,
#             "profile_link_color": "DD2E44",
#             "protected": false,
#             "statuses_count": 2055,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/402374064/1442149779",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/667991763152461824/o-b7GyeK_normal.jpg",
#             "has_extended_profile": false,
#             "name": "Beyond'O'cracy",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "id": 402374064,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": false,
#             "notifications": false,
#             "utc_offset": -25200,
#             "profile_background_color": "000000",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "000000",
#             "default_profile": false,
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/siyuFNUGnc",
#                             "expanded_url": "http://www.beyondent.tv",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "display_url": "beyondent.tv"
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "followers_count": 554,
#             "is_translator": false,
#             "time_zone": "Pacific Time (US & Canada)",
#             "favourites_count": 7,
#             "default_profile_image": false,
#             "id_str": "402374064",
#             "description": "Entertainment of the People, for the People and by the People. BEntertained! #MoreThanMusic"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Fri Sep 09 00:36:41 +0000 2016",
#         "id": 774043814570831872,
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "RT @underground_ng: [WATCH VIDEO] Teyana Taylor Brings Kanye West's \"Fade\" Video to Life (Explicit) - https://t.co/IErycULCY6\n#Kanye #yeezy\u2026",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [
#                 {
#                     "name": "#HipHopCommunity",
#                     "indices": [
#                         3,
#                         18
#                     ],
#                     "screen_name": "underground_ng",
#                     "id": 3488747777,
#                     "id_str": "3488747777"
#                 }
#             ],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         126,
#                         132
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         133,
#                         139
#                     ],
#                     "text": "yeezy"
#                 },
#                 {
#                     "indices": [
#                         139,
#                         140
#                     ],
#                     "text": "KanyeWest"
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/IErycULCY6",
#                     "expanded_url": "http://undergroundcontest.com/kanye-west-fade-explicit/",
#                     "indices": [
#                         102,
#                         125
#                     ],
#                     "display_url": "undergroundcontest.com/kanye-west-fad\u2026"
#                 }
#             ]
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774043814570831872"
#     },
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 0,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "place": null,
#         "user": {
#             "url": null,
#             "created_at": "Sun Mar 29 07:04:43 +0000 2009",
#             "contributors_enabled": false,
#             "geo_enabled": true,
#             "verified": false,
#             "profile_text_color": "333333",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/767518198761750528/exqCOUrr_normal.jpg",
#             "following": false,
#             "listed_count": 2,
#             "profile_sidebar_border_color": "DFDFDF",
#             "location": "United States",
#             "friends_count": 475,
#             "screen_name": "LMWooHoo",
#             "profile_background_tile": false,
#             "profile_link_color": "990000",
#             "protected": false,
#             "statuses_count": 76904,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/27394733/1471575098",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/767518198761750528/exqCOUrr_normal.jpg",
#             "has_extended_profile": true,
#             "name": "wendy \ud83d\udc78\ud83c\udffb",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme7/bg.gif",
#             "id": 27394733,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme7/bg.gif",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "notifications": false,
#             "utc_offset": -14400,
#             "profile_background_color": "EBEBEB",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "F3F3F3",
#             "default_profile": false,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "followers_count": 670,
#             "is_translator": false,
#             "time_zone": "Eastern Time (US & Canada)",
#             "favourites_count": 1492,
#             "default_profile_image": false,
#             "id_str": "27394733",
#             "description": "\u2764\ufe0f"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Fri Sep 09 00:34:02 +0000 2016",
#         "id": 774043150230753282,
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "Chasing my patron with corona tonight #lit #Kanye #TheLifeOfPablo #endofsummer16 #whereskimk",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         38,
#                         42
#                     ],
#                     "text": "lit"
#                 },
#                 {
#                     "indices": [
#                         43,
#                         49
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         50,
#                         65
#                     ],
#                     "text": "TheLifeOfPablo"
#                 },
#                 {
#                     "indices": [
#                         66,
#                         80
#                     ],
#                     "text": "endofsummer16"
#                 },
#                 {
#                     "indices": [
#                         81,
#                         92
#                     ],
#                     "text": "whereskimk"
#                 }
#             ],
#             "urls": []
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774043150230753282"
#     },
#     {
#         "in_reply_to_screen_name": null,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "lang": "en",
#         "retweet_count": 1,
#         "geo": null,
#         "in_reply_to_status_id": null,
#         "coordinates": null,
#         "favorite_count": 0,
#         "place": null,
#         "retweeted_status": {
#             "in_reply_to_screen_name": null,
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "lang": "en",
#             "retweet_count": 1,
#             "geo": null,
#             "in_reply_to_status_id": null,
#             "coordinates": null,
#             "favorite_count": 0,
#             "place": null,
#             "user": {
#                 "url": "https://t.co/PoO0kWrMTp",
#                 "created_at": "Sun Apr 24 03:40:40 +0000 2016",
#                 "contributors_enabled": false,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "profile_text_color": "000000",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/758846831803535360/55J7E-18_normal.jpg",
#                 "following": false,
#                 "listed_count": 6,
#                 "profile_sidebar_border_color": "000000",
#                 "location": "The Top",
#                 "friends_count": 372,
#                 "screen_name": "jmpman",
#                 "profile_background_tile": false,
#                 "profile_link_color": "ABB8C2",
#                 "protected": false,
#                 "statuses_count": 2434,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/724080589456830464/1473092710",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/758846831803535360/55J7E-18_normal.jpg",
#                 "has_extended_profile": true,
#                 "name": "Jack\ud83c\udfa7",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "id": 724080589456830464,
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "lang": "en",
#                 "follow_request_sent": false,
#                 "profile_use_background_image": false,
#                 "notifications": false,
#                 "utc_offset": -14400,
#                 "profile_background_color": "000000",
#                 "is_translation_enabled": false,
#                 "profile_sidebar_fill_color": "000000",
#                 "default_profile": false,
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/PoO0kWrMTp",
#                                 "expanded_url": "https://soundcloud.com/user-660682492",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "display_url": "soundcloud.com/user-660682492"
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "followers_count": 369,
#                 "is_translator": false,
#                 "time_zone": "EDT",
#                 "favourites_count": 2373,
#                 "default_profile_image": false,
#                 "id_str": "724080589456830464",
#                 "description": "Snapchat: ovo220"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_user_id": null,
#             "created_at": "Thu Sep 08 23:22:03 +0000 2016",
#             "id": 774025033479917568,
#             "contributors": null,
#             "in_reply_to_user_id_str": null,
#             "text": "Take your pick\ud83e\udd14 #drake #kanye #pablo #OVO #Summersixteen #LifeofPablo #Future #collab #mixtape #studio #album",
#             "retweeted": false,
#             "is_quote_status": false,
#             "entities": {
#                 "user_mentions": [],
#                 "symbols": [],
#                 "hashtags": [
#                     {
#                         "indices": [
#                             16,
#                             22
#                         ],
#                         "text": "drake"
#                     },
#                     {
#                         "indices": [
#                             23,
#                             29
#                         ],
#                         "text": "kanye"
#                     },
#                     {
#                         "indices": [
#                             30,
#                             36
#                         ],
#                         "text": "pablo"
#                     },
#                     {
#                         "indices": [
#                             37,
#                             41
#                         ],
#                         "text": "OVO"
#                     },
#                     {
#                         "indices": [
#                             42,
#                             56
#                         ],
#                         "text": "Summersixteen"
#                     },
#                     {
#                         "indices": [
#                             57,
#                             69
#                         ],
#                         "text": "LifeofPablo"
#                     },
#                     {
#                         "indices": [
#                             70,
#                             77
#                         ],
#                         "text": "Future"
#                     },
#                     {
#                         "indices": [
#                             78,
#                             85
#                         ],
#                         "text": "collab"
#                     },
#                     {
#                         "indices": [
#                             86,
#                             94
#                         ],
#                         "text": "mixtape"
#                     },
#                     {
#                         "indices": [
#                             95,
#                             102
#                         ],
#                         "text": "studio"
#                     },
#                     {
#                         "indices": [
#                             103,
#                             109
#                         ],
#                         "text": "album"
#                     }
#                 ],
#                 "urls": []
#             },
#             "favorited": false,
#             "in_reply_to_status_id_str": null,
#             "truncated": false,
# ...
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_user_id": null,
#             "created_at": "Thu Sep 08 20:13:30 +0000 2016",
#             "id": 773977582211563521,
#             "extended_entities": {
#                 "media": [
#                     {
#                         "indices": [
#                             110,
#                             133
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                         "sizes": {
#                             "medium": {
#                                 "resize": "fit",
#                                 "w": 1200,
#                                 "h": 1200
#                             },
#                             "thumb": {
#                                 "resize": "crop",
#                                 "w": 150,
#                                 "h": 150
#                             },
#                             "small": {
#                                 "resize": "fit",
#                                 "w": 680,
#                                 "h": 680
#                             },
#                             "large": {
#                                 "resize": "fit",
#                                 "w": 1512,
#                                 "h": 1512
#                             }
#                         },
#                         "id": 773977561693028352,
#                         "expanded_url": "https://twitter.com/itsss_donar/status/773977582211563521/photo/1",
#                         "media_url_https": "https://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                         "url": "https://t.co/bQwpBt1PZQ",
#                         "type": "photo",
#                         "id_str": "773977561693028352",
#                         "display_url": "pic.twitter.com/bQwpBt1PZQ"
#                     }
#                 ]
#             },
#             "contributors": null,
#             "in_reply_to_user_id_str": null,
#             "text": "#downhill #vegas #art #GUCCI #Nike #Kanye #clothingdesign #tommyhilfiger #GUESS #heat #DontSleep\nPlease share https://t.co/bQwpBt1PZQ",
#             "retweeted": false,
#             "is_quote_status": false,
#             "entities": {
#                 "user_mentions": [],
#                 "symbols": [],
#                 "hashtags": [
#                     {
#                         "indices": [
#                             0,
#                             9
#                         ],
#                         "text": "downhill"
#                     },
#                     {
#                         "indices": [
#                             10,
#                             16
#                         ],
#                         "text": "vegas"
#                     },
#                     {
#                         "indices": [
#                             17,
#                             21
#                         ],
#                         "text": "art"
#                     },
#                     {
#                         "indices": [
#                             22,
#                             28
#                         ],
#                         "text": "GUCCI"
#                     },
#                     {
#                         "indices": [
#                             29,
#                             34
#                         ],
#                         "text": "Nike"
#                     },
#                     {
#                         "indices": [
#                             35,
#                             41
#                         ],
#                         "text": "Kanye"
#                     },
#                     {
#                         "indices": [
#                             42,
#                             57
#                         ],
#                         "text": "clothingdesign"
#                     },
#                     {
#                         "indices": [
#                             58,
#                             72
#                         ],
#                         "text": "tommyhilfiger"
#                     },
#                     {
#                         "indices": [
#                             73,
#                             79
#                         ],
#                         "text": "GUESS"
#                     },
#                     {
#                         "indices": [
#                             80,
#                             85
#                         ],
#                         "text": "heat"
#                     },
#                     {
#                         "indices": [
#                             86,
#                             96
#                         ],
#                         "text": "DontSleep"
#                     }
#                 ],
#                 "media": [
#                     {
#                         "indices": [
#                             110,
#                             133
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                         "sizes": {
#                             "medium": {
#                                 "resize": "fit",
#                                 "w": 1200,
#                                 "h": 1200
#                             },
#                             "thumb": {
#                                 "resize": "crop",
#                                 "w": 150,
#                                 "h": 150
#                             },
#                             "small": {
#                                 "resize": "fit",
#                                 "w": 680,
#                                 "h": 680
#                             },
#                             "large": {
#                                 "resize": "fit",
#                                 "w": 1512,
#                                 "h": 1512
#                             }
#                         },
#                         "id": 773977561693028352,
#                         "expanded_url": "https://twitter.com/itsss_donar/status/773977582211563521/photo/1",
#                         "media_url_https": "https://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                         "url": "https://t.co/bQwpBt1PZQ",
#                         "type": "photo",
#                         "id_str": "773977561693028352",
#                         "display_url": "pic.twitter.com/bQwpBt1PZQ"
#                     }
#                 ],
#                 "urls": []
#             },
#             "favorited": false,
#             "in_reply_to_status_id_str": null,
#             "truncated": false,
#             "id_str": "773977582211563521"
#         },
#         "user": {
#             "url": "https://t.co/vy2OdTD3lt",
#             "created_at": "Fri Jun 08 04:55:00 +0000 2012",
#             "contributors_enabled": false,
#             "geo_enabled": true,
#             "verified": false,
#             "profile_text_color": "CA5244",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/767557344368570368/XZd0JC_E_normal.jpg",
#             "following": false,
#             "listed_count": 2,
#             "profile_sidebar_border_color": "FFFFFF",
#             "location": "jupiter and mars.",
#             "friends_count": 481,
#             "screen_name": "daddyantae",
#             "profile_background_tile": true,
#             "profile_link_color": "D4263F",
#             "protected": false,
#             "statuses_count": 10037,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/602470931/1472500927",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/767557344368570368/XZd0JC_E_normal.jpg",
#             "has_extended_profile": true,
#             "name": "ICEEYHOT",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/715128485/b7747c7da43c273031204e4960904db7.jpeg",
#             "id": 602470931,
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/715128485/b7747c7da43c273031204e4960904db7.jpeg",
#             "lang": "en",
#             "follow_request_sent": false,
#             "profile_use_background_image": true,
#             "notifications": false,
#             "utc_offset": -25200,
#             "profile_background_color": "2B281F",
#             "is_translation_enabled": false,
#             "profile_sidebar_fill_color": "B2745F",
#             "default_profile": false,
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/vy2OdTD3lt",
#                             "expanded_url": "http://xvideos.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "display_url": "xvideos.com"
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "followers_count": 593,
#             "is_translator": false,
#             "time_zone": "Arizona",
#             "favourites_count": 3300,
#             "default_profile_image": false,
#             "id_str": "602470931",
#             "description": "ctr. alt. del."
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_user_id": null,
#         "created_at": "Thu Sep 08 22:15:51 +0000 2016",
#         "id": 774008373519933445,
#         "extended_entities": {
#             "media": [
#                 {
#                     "url": "https://t.co/bQwpBt1PZQ",
#                     "media_url": "http://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                     "sizes": {
#                         "medium": {
#                             "resize": "fit",
#                             "w": 1200,
#                             "h": 1200
#                         },
#                         "thumb": {
#                             "resize": "crop",
#                             "w": 150,
#                             "h": 150
#                         },
#                         "small": {
#                             "resize": "fit",
#                             "w": 680,
#                             "h": 680
#                         },
#                         "large": {
#                             "resize": "fit",
#                             "w": 1512,
#                             "h": 1512
#                         }
#                     },
#                     "id": 773977561693028352,
#                     "expanded_url": "https://twitter.com/itsss_donar/status/773977582211563521/photo/1",
#                     "source_user_id_str": "2480834822",
#                     "media_url_https": "https://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                     "type": "photo",
#                     "indices": [
#                         139,
#                         140
#                     ],
#                     "source_status_id": 773977582211563521,
#                     "source_user_id": 2480834822,
#                     "source_status_id_str": "773977582211563521",
#                     "id_str": "773977561693028352",
#                     "display_url": "pic.twitter.com/bQwpBt1PZQ"
#                 }
#             ]
#         },
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "text": "RT @itsss_donar: #downhill #vegas #art #GUCCI #Nike #Kanye #clothingdesign #tommyhilfiger #GUESS #heat #DontSleep\nPlease share https://t.co\u2026",
#         "retweeted": false,
#         "is_quote_status": false,
#         "entities": {
#             "user_mentions": [
#                 {
#                     "name": "downhill.co",
#                     "indices": [
#                         3,
#                         15
#                     ],
#                     "screen_name": "itsss_donar",
#                     "id": 2480834822,
#                     "id_str": "2480834822"
#                 }
#             ],
#             "symbols": [],
#             "hashtags": [
#                 {
#                     "indices": [
#                         17,
#                         26
#                     ],
#                     "text": "downhill"
#                 },
#                 {
#                     "indices": [
#                         27,
#                         33
#                     ],
#                     "text": "vegas"
#                 },
#                 {
#                     "indices": [
#                         34,
#                         38
#                     ],
#                     "text": "art"
#                 },
#                 {
#                     "indices": [
#                         39,
#                         45
#                     ],
#                     "text": "GUCCI"
#                 },
#                 {
#                     "indices": [
#                         46,
#                         51
#                     ],
#                     "text": "Nike"
#                 },
#                 {
#                     "indices": [
#                         52,
#                         58
#                     ],
#                     "text": "Kanye"
#                 },
#                 {
#                     "indices": [
#                         59,
#                         74
#                     ],
#                     "text": "clothingdesign"
#                 },
#                 {
#                     "indices": [
#                         75,
#                         89
#                     ],
#                     "text": "tommyhilfiger"
#                 },
#                 {
#                     "indices": [
#                         90,
#                         96
#                     ],
#                     "text": "GUESS"
#                 },
#                 {
#                     "indices": [
#                         97,
#                         102
#                     ],
#                     "text": "heat"
#                 },
#                 {
#                     "indices": [
#                         103,
#                         113
#                     ],
#                     "text": "DontSleep"
#                 }
#             ],
#             "media": [
#                 {
#                     "url": "https://t.co/bQwpBt1PZQ",
#                     "media_url": "http://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                     "sizes": {
#                         "medium": {
#                             "resize": "fit",
#                             "w": 1200,
#                             "h": 1200
#                         },
#                         "thumb": {
#                             "resize": "crop",
#                             "w": 150,
#                             "h": 150
#                         },
#                         "small": {
#                             "resize": "fit",
#                             "w": 680,
#                             "h": 680
#                         },
#                         "large": {
#                             "resize": "fit",
#                             "w": 1512,
#                             "h": 1512
#                         }
#                     },
#                     "id": 773977561693028352,
#                     "expanded_url": "https://twitter.com/itsss_donar/status/773977582211563521/photo/1",
#                     "source_user_id_str": "2480834822",
#                     "media_url_https": "https://pbs.twimg.com/media/Cr24fdzWAAAKjnW.jpg",
#                     "type": "photo",
#                     "indices": [
#                         139,
#                         140
#                     ],
#                     "source_status_id": 773977582211563521,
#                     "source_user_id": 2480834822,
#                     "source_status_id_str": "773977582211563521",
#                     "id_str": "773977561693028352",
#                     "display_url": "pic.twitter.com/bQwpBt1PZQ"
#                 }
#             ],
#             "urls": []
#         },
#         "favorited": false,
#         "in_reply_to_status_id_str": null,
#         "truncated": false,
#         "id_str": "774008373519933445"
#     }
# ]

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 6. Extracting text, screen names, and hashtags from tweets

# %%
import time


status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "And Kanye falls victim to my \"their older albums were better\" comments. Join the club #kanye #falloutboy #panicatthedisco",
#  "Waiting for #Kanye #SaintPabloTour https://t.co/pgxhqGxHPl",
#  "anyone selling tickets for Kanye West in Dallas? HMU need 2 #SaintPabloTour #kanye #dallas #AmericanAirlines",
#  "Real friends. How many of us? How many jealous? Saturday Sept.17th Fall '16 drops! \ud83c\udf0a #existenceapparel #kanye #yeezy https://t.co/FdTtrN9CdW",
#  "Anyone in #DC need a #kanye ticket right now? Heading into show and have one extra. Can transfer ticket electronically"
# ]
# [
#  "underground_ng",
#  "jmpman",
#  "thedailybeast",
#  "EyeKonik",
#  "TymberleeHill"
# ]
# [
#  "kanye",
#  "falloutboy",
#  "panicatthedisco",
#  "Kanye",
#  "SaintPabloTour"
# ]
# [
#  "And",
#  "Kanye",
#  "falls",
#  "victim",
#  "to"
# ]

# %% [markdown]
# # Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [('#Kanye', 44), ('#kanye', 28), ('RT', 23), ('a', 15), ('to', 15), ('the', 13), ('in', 12), ('be', 10), ('#Yeezy', 10), ('@', 8)]
# [('RichKurtzman', 3), ('EyeKonik', 3), ('kanyewest', 3), ('TymberleeHill', 2), ('ESTribune', 2), ('itsss_donar', 2), ('HouseofQE1', 2), ('ChemistEnt', 2), ('thedailybeast', 1), ('liskhalifa', 1)]
# [('Kanye', 50), ('kanye', 30), ('Yeezy', 10), ('Broncos', 7), ('KanyeWest', 7), ('SaintPabloTour', 7), ('Drake', 6), ('drake', 4), ('MGWV', 3), ('E40', 3)]

# %% [markdown]
# # Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +--------+-------+
# | Word   | Count |
# +--------+-------+
# | #Kanye |    44 |
# | #kanye |    28 |
# | RT     |    23 |
# | a      |    15 |
# | to     |    15 |
# | the    |    13 |
# | in     |    12 |
# | be     |    10 |
# | #Yeezy |    10 |
# | @      |     8 |
# +--------+-------+
# +---------------+-------+
# | Screen Name   | Count |
# +---------------+-------+
# | RichKurtzman  |     3 |
# | EyeKonik      |     3 |
# | kanyewest     |     3 |
# | TymberleeHill |     2 |
# | ESTribune     |     2 |
# | itsss_donar   |     2 |
# | HouseofQE1    |     2 |
# | ChemistEnt    |     2 |
# | thedailybeast |     1 |
# | liskhalifa    |     1 |
# +---------------+-------+
# +----------------+-------+
# | Hashtag        | Count |
# +----------------+-------+
# | Kanye          |    50 |
# | kanye          |    30 |
# | Yeezy          |    10 |
# | Broncos        |     7 |
# | KanyeWest      |     7 |
# | SaintPabloTour |     7 |
# | Drake          |     6 |
# | drake          |     4 |
# | MGWV           |     3 |
# | E40            |     3 |
# +----------------+-------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.5415224913494809
# 0.725
# 0.4260869565217391
# 14.271604938271604

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-------------+----------------------------------------------------+
# | Count | Screen Name | Text                                               |
# +-------+-------------+----------------------------------------------------+
# | 120   | EyeKonik    | RT @EyeKonik: https://t.co/cqnKD3YQGq              |
# |       |             | #zen #EYEKONIK #MGWV #Kanye #trump #clinton #RT    |
# |       |             | #trending #rapper #howto #music #SnoopDogg #E40    |
# |       |             | #Brun…                                             |
# | 120   | EyeKonik    | RT @EyeKonik: https://t.co/cqnKD3YQGq              |
# |       |             | #zen #EYEKONIK #MGWV #Kanye #trump #clinton #RT    |
# |       |             | #trending #rapper #howto #music #SnoopDogg #E40    |
# |       |             | #Brun…                                             |
# | 120   | EyeKonik    | RT @EyeKonik: https://t.co/cqnKD3YQGq              |
# |       |             | #zen #EYEKONIK #MGWV #Kanye #trump #clinton #RT    |
# |       |             | #trending #rapper #howto #music #SnoopDogg #E40    |
# |       |             | #Brun…                                             |
# | 34    | Footaction  | RT @Footaction: #Kanye has announced he's working  |
# |       |             | on an album with #Drake 👀. Which is your favorite  |
# |       |             | album collab of these artists?                     |
# | 19    | ChemistEnt  | RT @ChemistEnt: #Kanye &amp; #Drake will           |
# |       |             | officially be making a joint album. Will this be   |
# |       |             | strictly on Tidal for a way to help out Jay Z?     |
# |       |             | https:…                                            |
# +-------+-------------+----------------------------------------------------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# #  Example 11. Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# # Example 12. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
# Out:
# [1, 1, 4, 120, 2, 2, 1, 1, 1, 1, 3, 19, 120, 120, 1, 3, 19, 1, 3, 3, 34, 6, 3]
